# %% [markdown]
# # Three Generations

# %% [markdown]
# from google.colab import drive
# drive.mount("/content/drive")

# %% [markdown]
# from google.colab import files
# uploaded = files.upload()

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("profiles.csv")
df.tail()
# Out:
#        age body_type diet drinks drugs education essay0 essay1 essay2 essay3  \
# 60547  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
# 60548  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
# 60549  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
# 60550  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
# 60551  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
#
#        ... location offspring orientation pets religion  sex sign  smokes  \
# 60547  ...      NaN       NaN         NaN  NaN      NaN  NaN  NaN     NaN
# 60548  ...      NaN       NaN         NaN  NaN      NaN  NaN  NaN     NaN
# 60549  ...      NaN       NaN         NaN  NaN      NaN  NaN  NaN     NaN
# 60550  ...      NaN       NaN         NaN  NaN      NaN  NaN  NaN     NaN
# 60551  ...      NaN       NaN         NaN  NaN      NaN  NaN  NaN     NaN
#
#        speaks status
# 60547     NaN    NaN
# ...

# %%
df.columns
# Out:
# Index(['age', 'body_type', 'diet', 'drinks', 'drugs', 'education', 'essay0',
#        'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7',
#        'essay8', 'essay9', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'orientation', 'pets',
#        'religion', 'sex', 'sign', 'smokes', 'speaks', 'status'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# age            51038
# body_type      51886
# diet           54791
# drinks         51540
# drugs          53337
# education      52093
# essay0         51885
# essay1         52205
# essay2         52503
# essay3         52862
# essay4         52673
# essay5         52738
# essay6         53200
# essay7         52999
# essay8         54191
# essay9         52998
# ethnicity      51987
# height         51038
# income         51038
# job            52369
# last_online    51038
# location       51038
# offspring      56666
# orientation    51038
# pets           54200
# religion       54291
# sex            51038
# sign           52776
# smokes         51956
# speaks         51044
# status         51038
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60552 entries, 0 to 60551
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          9514 non-null   float64
#  1   body_type    8666 non-null   object
#  2   diet         5761 non-null   object
#  3   drinks       9012 non-null   object
#  4   drugs        7215 non-null   object
#  5   education    8459 non-null   object
#  6   essay0       8667 non-null   object
#  7   essay1       8347 non-null   object
#  8   essay2       8049 non-null   object
#  9   essay3       7690 non-null   object
#  10  essay4       7879 non-null   object
#  11  essay5       7814 non-null   object
#  12  essay6       7352 non-null   object
#  13  essay7       7553 non-null   object
#  14  essay8       6361 non-null   object
#  15  essay9       7554 non-null   object
#  16  ethnicity    8565 non-null   object
#  17  height       9514 non-null   float64
# ...

# %%
df.shape
# Out:
# (60552, 31)

# %%
df_new = df.iloc[:9514]

# %%
bos = df.iloc[9514:]

# %%
bos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51038 entries, 9514 to 60551
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          0 non-null      float64
#  1   body_type    0 non-null      object
#  2   diet         0 non-null      object
#  3   drinks       0 non-null      object
#  4   drugs        0 non-null      object
#  5   education    0 non-null      object
#  6   essay0       0 non-null      object
#  7   essay1       0 non-null      object
#  8   essay2       0 non-null      object
#  9   essay3       0 non-null      object
#  10  essay4       0 non-null      object
#  11  essay5       0 non-null      object
#  12  essay6       0 non-null      object
#  13  essay7       0 non-null      object
#  14  essay8       0 non-null      object
#  15  essay9       0 non-null      object
#  16  ethnicity    0 non-null      object
#  17  height       0 non-null      float64
# ...

# %%
df_new.speaks.value_counts()
# Out:
# english                                                                                3415
# english (fluently)                                                                     1106
# english (fluently), spanish (okay)                                                      322
# english (fluently), spanish (poorly)                                                    321
# english (fluently), spanish (fluently)                                                  195
#                                                                                        ...
# english (fluently), hindi (fluently), spanish (okay)                                      1
# english (fluently), danish (fluently), spanish (okay), german (poorly)                    1
# english (fluently), spanish (fluently), portuguese                                        1
# english (fluently), arabic (fluently), spanish (okay), urdu (okay), gujarati (okay)       1
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9514 entries, 0 to 9513
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          9514 non-null   float64
#  1   body_type    8666 non-null   object
#  2   diet         5761 non-null   object
#  3   drinks       9012 non-null   object
#  4   drugs        7215 non-null   object
#  5   education    8459 non-null   object
#  6   essay0       8667 non-null   object
#  7   essay1       8347 non-null   object
#  8   essay2       8049 non-null   object
#  9   essay3       7690 non-null   object
#  10  essay4       7879 non-null   object
#  11  essay5       7814 non-null   object
#  12  essay6       7352 non-null   object
#  13  essay7       7553 non-null   object
#  14  essay8       6361 non-null   object
#  15  essay9       7554 non-null   object
#  16  ethnicity    8565 non-null   object
#  17  height       9514 non-null   float64
# ...

# %%
df_new.isnull().sum()
# Out:
# age               0
# body_type       848
# diet           3753
# drinks          502
# drugs          2299
# education      1055
# essay0          847
# essay1         1167
# essay2         1465
# essay3         1824
# essay4         1635
# essay5         1700
# essay6         2162
# essay7         1961
# essay8         3153
# essay9         1960
# ethnicity       949
# height            0
# income            0
# job            1331
# last_online       0
# location          0
# offspring      5628
# orientation       0
# pets           3162
# religion       3253
# sex               0
# sign           1738
# smokes          918
# speaks            6
# status            0
# dtype: int64

# %%
# Boşluk Doldurma

# %%
del df_new["offspring"]

# %%
df_new = df_new.drop(["essay0","essay1","essay2","essay3","essay4","essay5","essay6","essay7","essay8","essay9"], axis=1)

# %%
df_new.pets.value_counts()
# Out:
# likes dogs and likes cats          2314
# likes dogs                         1152
# has dogs                            683
# likes dogs and has cats             674
# has dogs and likes cats             384
# likes dogs and dislikes cats        301
# has dogs and has cats               226
# has cats                            221
# likes cats                          200
# has dogs and dislikes cats           82
# dislikes dogs and dislikes cats      42
# dislikes dogs and likes cats         36
# dislikes cats                        20
# dislikes dogs and has cats           13
# dislikes dogs                         4
# Name: pets, dtype: int64

# %%
df_new["speaks"].fillna("english",inplace=True)

# %%
df_new["body_type"].fillna("average",inplace=True)

# %%
df_new["diet"].fillna("mostly anything",inplace=True)

# %%
df_new["drinks"].fillna("socially",inplace=True)

# %%
df_new["drugs"].fillna("never",inplace=True)

# %%
df_new["education"].fillna("nevgraduated from college/universityer",inplace=True,limit=800)

# %%
df_new["education"].fillna("graduated from masters program",inplace=True,limit=255)

# %%
df_new["job"].fillna("other",inplace=True)

# %%
df_new["smokes"].fillna("no",inplace=True)

# %%
df_new["ethnicity"].fillna("white",inplace=True)

# %% [markdown]
# ## Pets

# %%
df_pets = df_new.drop(["religion","sign"], axis=1)

# %%
df_pets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9514 entries, 0 to 9513
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          9514 non-null   float64
#  1   body_type    9514 non-null   object
#  2   diet         9514 non-null   object
#  3   drinks       9514 non-null   object
#  4   drugs        9514 non-null   object
#  5   education    9514 non-null   object
#  6   ethnicity    9514 non-null   object
#  7   height       9514 non-null   float64
#  8   income       9514 non-null   float64
#  9   job          9514 non-null   object
#  10  last_online  9514 non-null   object
#  11  location     9514 non-null   object
#  12  orientation  9514 non-null   object
#  13  pets         6352 non-null   object
#  14  sex          9514 non-null   object
#  15  smokes       9514 non-null   object
#  16  speaks       9514 non-null   object
#  17  status       9514 non-null   object
# ...

# %%
df_pets = df_pets.sort_values("pets")
df_pets.head()
# Out:
#        age body_type               diet    drinks  drugs  \
# 9494  28.0       fit    mostly anything  socially  never
# 6646  20.0      thin    mostly anything    rarely  never
# 415   59.0   average           anything  socially  never
# 7631  26.0   average  strictly anything  socially  never
# 5257  20.0   average    mostly anything  socially  never
#
#                               education     ethnicity  height   income  \
# 9494  graduated from college/university  white, other    61.0     -1.0
# 6646  dropped out of college/university         other    71.0  70000.0
# 415   graduated from college/university         other    71.0     -1.0
# 7631          graduated from law school         white    70.0     -1.0
# 5257      working on college/university         white    67.0     -1.0
#
#                                job       last_online  \
# 9494                         other  2012-06-04-18-01
# 6646          education / academia  2012-06-29-23-46
# ...

# %%
pets = df_pets["pets"]

# %%
pets.iloc[6351]
# Out:
# 'likes dogs and likes cats'

# %%
pets.head()
# Out:
# 9494    dislikes cats
# 6646    dislikes cats
# 415     dislikes cats
# 7631    dislikes cats
# 5257    dislikes cats
# Name: pets, dtype: object

# %%
df_pets.isnull().sum()
# Out:
# age               0
# body_type         0
# diet              0
# drinks            0
# drugs             0
# education         0
# ethnicity         0
# height            0
# income            0
# job               0
# last_online       0
# location          0
# orientation       0
# pets           3162
# sex               0
# smokes            0
# speaks            0
# status            0
# dtype: int64

# %%
df_pets.pets.iloc[6351]
# Out:
# 'likes dogs and likes cats'

# %%
del df_pets["pets"]

# %%
df_pets = pd.get_dummies(df_pets,drop_first=True)

# %%
df_pets_train = df_pets[:6352]
df_pets_train.tail(1)
# Out:
#        age  height  income  body_type_athletic  body_type_average  \
# 9513  49.0    64.0    -1.0                   0                  0
#
#       body_type_curvy  body_type_fit  body_type_full figured  \
# 9513                0              0                       0
#
#       body_type_jacked  body_type_overweight  ...  \
# 9513                 0                     1  ...
#
#       speaks_english, urdu, french, arabic, russian (poorly)  \
# 9513                                                  0
#
#       speaks_english, vietnamese  speaks_english, vietnamese (okay)  \
# 9513                           0                                  0
#
#       speaks_english, vietnamese (okay), spanish (okay)  \
# 9513                                                  0
#
#       speaks_english, vietnamese (poorly)  \
# 9513                                    0
#
#       speaks_english, vietnamese, spanish  speaks_english, yiddish (poorly)  \
# ...

# %%
df_pets_test = pets[:6352]
df_pets_test.tail(1)
# Out:
# 9513    likes dogs and likes cats
# Name: pets, dtype: object

# %%
df_pets_test.shape
# Out:
# (6352,)

# %%
df_pets_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6352 entries, 9494 to 9513
# Columns: 8853 entries, age to status_single
# dtypes: float64(3), uint8(8850)
# memory usage: 53.8 MB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)

# Regression

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.preprocessing import normalize,scale

# Classification

from sklearn.naive_bayes import MultinomialNB,GaussianNB,BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

# %%
def classification_(train,y):
    
    
    g = GaussianNB()
    b = BernoulliNB()
    k = KNeighborsClassifier()
    svc = SVC()
    d = DecisionTreeClassifier()
    log = LogisticRegression()
    gbc = GradientBoostingClassifier()
    mn = MultinomialNB()
    rf = RandomForestClassifier()
    ab = AdaBoostClassifier()

    x = train
    y = y
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = .2, random_state=42)
    algos = [g,b,k,svc,d,log,gbc,mn,rf,ab]
    algos_name = ['Gaussian','Bernoulli','KNeigbors','SVC','DecisionTree','LogisticRegr','GradientBoosting','Multinominal','RandomForest','AdaBoost']
    
    accuracy = []
    precision = []
    recall = []
    f1 = []
   
    result = pd.DataFrame(columns=['AccuracyScore','PrecisionScore','RecallScore','f1_Score'],index = algos_name)
    
    for i in algos:
        
        predict = i.fit(x_train,y_train).predict(x_test)
        
        accuracy.append(accuracy_score(y_test,predict))
        precision.append(precision_score(y_test,predict, average='micro'))
        recall.append(recall_score(y_test,predict, average='micro'))
        f1.append(f1_score(y_test,predict, average='micro'))
        

    
    
    result.AccuracyScore = accuracy
    result.PrecisionScore = precision
    result.RecallScore = recall
    result.f1_Score = f1
    
    
    return result.sort_values('f1_Score',ascending=False)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_pets_train_scaled = scaler.fit_transform(df_pets_train)

# %%
#classification_(df_pets_train_scaled,df_pets_test)

# %%
df_pets.shape
# Out:
# (9514, 8853)

# %%
df_pets
# Out:
#        age  height   income  body_type_athletic  body_type_average  \
# 9494  28.0    61.0     -1.0                   0                  0
# 6646  20.0    71.0  70000.0                   0                  0
# 415   59.0    71.0     -1.0                   0                  1
# 7631  26.0    70.0     -1.0                   0                  1
# 5257  20.0    67.0     -1.0                   0                  1
# ...    ...     ...      ...                 ...                ...
# 9496  24.0    63.0     -1.0                   0                  1
# 9498  30.0    60.0     -1.0                   1                  0
# 9502  31.0    72.0     -1.0                   1                  0
# 9507  41.0    67.0     -1.0                   0                  0
# 9510  31.0    72.0     -1.0                   1                  0
#
#       body_type_curvy  body_type_fit  body_type_full figured  \
# 9494                0              1                       0
# ...

# %%
tahmin_pets = DecisionTreeClassifier().fit(df_pets_train_scaled,df_pets_test).predict(df_pets[6352:])

# %%
tahmin_pets
# Out:
# array(['likes dogs', 'has dogs and has cats', 'has cats', ...,
#        'likes dogs and likes cats', 'likes dogs and dislikes cats',
#        'likes dogs and likes cats'], dtype=object)

# %%
len(tahmin_pets)
# Out:
# 3162

# %%
#tahmin_pets = pd.Series(tahmin_pets)

# %%
pets.isnull().sum()
# Out:
# 3162

# %%
pets1 = pets[:6352]
pets1.tail(1)
# Out:
# 9513    likes dogs and likes cats
# Name: pets, dtype: object

# %%
pets1 = pd.Series(pets1)

# %%
type(pets1), type(tahmin_pets)
# Out:
# (pandas.core.series.Series, numpy.ndarray)

# %%
tahmin_pets = pd.Series(tahmin_pets)

# %%
pets_deneme = pets1.append(tahmin_pets)

# %%
pets_deneme
# Out:
# 9494                   dislikes cats
# 6646                   dislikes cats
# 415                    dislikes cats
# 7631                   dislikes cats
# 5257                   dislikes cats
#                     ...
# 3157                        has cats
# 3158                        has cats
# 3159       likes dogs and likes cats
# 3160    likes dogs and dislikes cats
# 3161       likes dogs and likes cats
# Length: 9514, dtype: object

# %%
len(pets_deneme)
# Out:
# 9514

# %% [markdown]
# ## Religion

# %%
df_religion = df_new.drop(["pets","sign"], axis=1)

# %%
df_religion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9514 entries, 0 to 9513
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          9514 non-null   float64
#  1   body_type    9514 non-null   object
#  2   diet         9514 non-null   object
#  3   drinks       9514 non-null   object
#  4   drugs        9514 non-null   object
#  5   education    9514 non-null   object
#  6   ethnicity    9514 non-null   object
#  7   height       9514 non-null   float64
#  8   income       9514 non-null   float64
#  9   job          9514 non-null   object
#  10  last_online  9514 non-null   object
#  11  location     9514 non-null   object
#  12  orientation  9514 non-null   object
#  13  religion     6261 non-null   object
#  14  sex          9514 non-null   object
#  15  smokes       9514 non-null   object
#  16  speaks       9514 non-null   object
#  17  status       9514 non-null   object
# ...

# %%
religion = df_religion["religion"]
religion = religion.sort_values()

# %%
religion.tail()
# Out:
# 9498    NaN
# 9499    NaN
# 9505    NaN
# 9512    NaN
# 9513    NaN
# Name: religion, dtype: object

# %%
df_religion.isnull().sum()
# Out:
# age               0
# body_type         0
# diet              0
# drinks            0
# drugs             0
# education         0
# ethnicity         0
# height            0
# income            0
# job               0
# last_online       0
# location          0
# orientation       0
# religion       3253
# sex               0
# smokes            0
# speaks            0
# status            0
# dtype: int64

# %%
df_religion = df_religion.sort_values("religion")
df_religion.head()
# Out:
#        age body_type             diet    drinks      drugs  \
# 1514  64.0  athletic         anything  socially      never
# 7709  32.0       fit  mostly anything     often      never
# 2213  46.0   average  mostly anything  socially  sometimes
# 2204  38.0   average  mostly anything  socially      never
# 2198  34.0  athletic         anything  socially      never
#
#                               education ethnicity  height   income  \
# 1514     graduated from masters program     white    73.0     -1.0
# 7709         working on masters program     white    74.0     -1.0
# 2213                 college/university     white    72.0  80000.0
# 2204     graduated from masters program     white    74.0     -1.0
# 2198  graduated from college/university     other    67.0     -1.0
#
#                                  job       last_online  \
# 1514                         retired  2012-06-29-19-18
# 7709            education / academia  2012-06-29-08-28
# ...

# %%
del df_religion["religion"]

# %%
df_religion = pd.get_dummies(df_religion,drop_first=True)

# %%
df_religion_train = df_religion[:6260]
df_religion_train.head()
# Out:
#        age  height   income  body_type_athletic  body_type_average  \
# 1514  64.0    73.0     -1.0                   1                  0
# 7709  32.0    74.0     -1.0                   0                  0
# 2213  46.0    72.0  80000.0                   0                  1
# 2204  38.0    74.0     -1.0                   0                  1
# 2198  34.0    67.0     -1.0                   1                  0
#
#       body_type_curvy  body_type_fit  body_type_full figured  \
# 1514                0              0                       0
# 7709                0              1                       0
# 2213                0              0                       0
# 2204                0              0                       0
# 2198                0              0                       0
#
#       body_type_jacked  body_type_overweight  body_type_rather not say  \
# 1514                 0                     0                         0
# ...

# %%
df_religion_test = religion[:6260]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)

# Regression

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.preprocessing import normalize,scale

# Classification

from sklearn.naive_bayes import MultinomialNB,GaussianNB,BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

# %%
def classification_(train,y):
    
    
    g = GaussianNB()
    b = BernoulliNB()
    k = KNeighborsClassifier()
    svc = SVC()
    d = DecisionTreeClassifier()
    log = LogisticRegression()
    gbc = GradientBoostingClassifier()
    mn = MultinomialNB()
    rf = RandomForestClassifier()
    ab = AdaBoostClassifier()

    x = train
    y = y
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = .2, random_state=42)
    algos = [g,b,k,svc,d,log,gbc,mn,rf,ab]
    algos_name = ['Gaussian','Bernoulli','KNeigbors','SVC','DecisionTree','LogisticRegr','GradientBoosting','Multinominal','RandomForest','AdaBoost']
    
    accuracy = []
    precision = []
    recall = []
    f1 = []
   
    result = pd.DataFrame(columns=['AccuracyScore','PrecisionScore','RecallScore','f1_Score'],index = algos_name)
    
    for i in algos:
        
        predict = i.fit(x_train,y_train).predict(x_test)
        
        accuracy.append(accuracy_score(y_test,predict))
        precision.append(precision_score(y_test,predict, average='micro'))
        recall.append(recall_score(y_test,predict, average='micro'))
        f1.append(f1_score(y_test,predict, average='micro'))
        

    
    
    result.AccuracyScore = accuracy
    result.PrecisionScore = precision
    result.RecallScore = recall
    result.f1_Score = f1
    
    
    return result.sort_values('f1_Score',ascending=False)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_religion_train_scaled = scaler.fit_transform(df_religion_train)

# %%
tahmin_religion = BernoulliNB().fit(df_religion_train_scaled,df_religion_test).predict(df_religion[6261:])

# %%
tahmin_religion
# Out:
# array(['agnosticism', 'agnosticism', 'agnosticism', ..., 'agnosticism',
#        'agnosticism', 'other'], dtype='<U42')

# %%
religion1 = religion[:6261]
religion1.tail(1)
# Out:
# 7581    other but not too serious about it
# Name: religion, dtype: object

# %%
religion1 = pd.Series(religion1)

# %%
tahmin_religion = pd.Series(tahmin_religion)

# %%
religion_deneme = religion1.append(tahmin_religion)

# %%
religion_deneme
# Out:
# 1514    agnosticism
# 7709    agnosticism
# 2213    agnosticism
# 2204    agnosticism
# 2198    agnosticism
#            ...
# 3248    agnosticism
# 3249    agnosticism
# 3250    agnosticism
# 3251    agnosticism
# 3252          other
# Length: 9514, dtype: object

# %%
len(religion_deneme)
# Out:
# 9514

# %% [markdown]
# ## Sign

# %%
df_sign = df_new.drop(["religion","pets"], axis=1)

# %%
df_sign.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9514 entries, 0 to 9513
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          9514 non-null   float64
#  1   body_type    9514 non-null   object
#  2   diet         9514 non-null   object
#  3   drinks       9514 non-null   object
#  4   drugs        9514 non-null   object
#  5   education    9514 non-null   object
#  6   ethnicity    9514 non-null   object
#  7   height       9514 non-null   float64
#  8   income       9514 non-null   float64
#  9   job          9514 non-null   object
#  10  last_online  9514 non-null   object
#  11  location     9514 non-null   object
#  12  orientation  9514 non-null   object
#  13  sex          9514 non-null   object
#  14  sign         7776 non-null   object
#  15  smokes       9514 non-null   object
#  16  speaks       9514 non-null   object
#  17  status       9514 non-null   object
# ...

# %%
sign = df_sign["sign"]
sign = sign.sort_values()

# %%
df_sign.isnull().sum()
# Out:
# age               0
# body_type         0
# diet              0
# drinks            0
# drugs             0
# education         0
# ethnicity         0
# height            0
# income            0
# job               0
# last_online       0
# location          0
# orientation       0
# sex               0
# sign           1738
# smokes            0
# speaks            0
# status            0
# dtype: int64

# %%
df_sign = df_sign.sort_values("sign")
df_sign.head()
# Out:
#        age body_type               diet    drinks  drugs  \
# 6250  28.0       fit    mostly anything     often  never
# 5581  45.0       fit    mostly anything  socially  never
# 1981  29.0   average    mostly anything     often  never
# 1971  30.0     curvy    mostly anything  socially  never
# 5649  42.0       fit  strictly anything  socially  never
#
#                                    education ethnicity  height  income  \
# 6250              working on masters program     black    68.0    -1.0
# 5581  nevgraduated from college/universityer     white    69.0    -1.0
# 1981  nevgraduated from college/universityer     white    72.0    -1.0
# 1971           working on college/university     white    64.0    -1.0
# 5649          graduated from masters program     white    66.0    -1.0
#
#                                  job       last_online  \
# 6250                         student  2012-06-29-10-30
# 5581  computer / hardware / software  2012-06-29-16-29
# ...

# %%
del df_sign["sign"]

# %%
df_sign = pd.get_dummies(df_sign,drop_first=True)

# %%
df_sign_train = df_sign[:7775]
df_sign_train.head()
# Out:
#        age  height  income  body_type_athletic  body_type_average  \
# 6250  28.0    68.0    -1.0                   0                  0
# 5581  45.0    69.0    -1.0                   0                  0
# 1981  29.0    72.0    -1.0                   0                  1
# 1971  30.0    64.0    -1.0                   0                  0
# 5649  42.0    66.0    -1.0                   0                  0
#
#       body_type_curvy  body_type_fit  body_type_full figured  \
# 6250                0              1                       0
# 5581                0              1                       0
# 1981                0              0                       0
# 1971                1              0                       0
# 5649                0              1                       0
#
#       body_type_jacked  body_type_overweight  body_type_rather not say  \
# 6250                 0                     0                         0
# ...

# %%
df_sign_test = sign[:7775]

# %%
df_sign_test.shape
# Out:
# (7775,)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)

# Regression

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.preprocessing import normalize,scale

# Classification

from sklearn.naive_bayes import MultinomialNB,GaussianNB,BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

# %%
def classification_(train,y):
    
    
    g = GaussianNB()
    b = BernoulliNB()
    k = KNeighborsClassifier()
    svc = SVC()
    d = DecisionTreeClassifier()
    log = LogisticRegression()
    gbc = GradientBoostingClassifier()
    mn = MultinomialNB()
    rf = RandomForestClassifier()
    ab = AdaBoostClassifier()

    x = train
    y = y
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = .2, random_state=42)
    algos = [g,b,k,svc,d,log,gbc,mn,rf,ab]
    algos_name = ['Gaussian','Bernoulli','KNeigbors','SVC','DecisionTree','LogisticRegr','GradientBoosting','Multinominal','RandomForest','AdaBoost']
    
    accuracy = []
    precision = []
    recall = []
    f1 = []
   
    result = pd.DataFrame(columns=['AccuracyScore','PrecisionScore','RecallScore','f1_Score'],index = algos_name)
    
    for i in algos:
        
        predict = i.fit(x_train,y_train).predict(x_test)
        
        accuracy.append(accuracy_score(y_test,predict))
        precision.append(precision_score(y_test,predict, average='micro'))
        recall.append(recall_score(y_test,predict, average='micro'))
        f1.append(f1_score(y_test,predict, average='micro'))
        

    
    
    result.AccuracyScore = accuracy
    result.PrecisionScore = precision
    result.RecallScore = recall
    result.f1_Score = f1
    
    
    return result.sort_values('f1_Score',ascending=False)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_sign_train_scaled = scaler.fit_transform(df_sign_train)

# %%
tahmin_sign = RandomForestClassifier().fit(df_sign_train_scaled,df_sign_test).predict(df_sign[7776:])

# %%
tahmin_sign
# Out:
# array(['cancer but it doesn&rsquo;t matter',
#        'leo and it&rsquo;s fun to think about', 'leo', ...,
#        'pisces and it&rsquo;s fun to think about',
#        'libra and it&rsquo;s fun to think about',
#        'pisces and it&rsquo;s fun to think about'], dtype=object)

# %%
len(tahmin_sign)
# Out:
# 1738

# %%
sign.isnull().sum()
# Out:
# 1738

# %%
len(sign)
# Out:
# 9514

# %%
sign1 = sign[:7776]
sign1.tail(1)
# Out:
# 5332    virgo but it doesn&rsquo;t matter
# Name: sign, dtype: object

# %%
sign1 = pd.Series(sign1)

# %%
tahmin_sign = pd.Series(tahmin_sign)

# %%
sign_deneme = sign1.append(tahmin_sign)

# %%
len(sign_deneme)
# Out:
# 9514

# %%
sign_deneme
# Out:
# 6250                                    aquarius
# 5581                                    aquarius
# 1981                                    aquarius
# 1971                                    aquarius
# 5649                                    aquarius
#                           ...
# 1733                                      taurus
# 1734           aries but it doesn&rsquo;t matter
# 1735    pisces and it&rsquo;s fun to think about
# 1736     libra and it&rsquo;s fun to think about
# 1737    pisces and it&rsquo;s fun to think about
# Length: 9514, dtype: object

# %% [markdown]
# # ----------------------------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)

# Regression

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.preprocessing import normalize,scale

# Classification

from sklearn.naive_bayes import MultinomialNB,GaussianNB,BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

# %%
def regression_(x,y):
    
    lr = LinearRegression()
    r = Ridge()
    l = Lasso()
    e = ElasticNet()
    kn = KNeighborsRegressor()
    ext = ExtraTreeRegressor()
    gb = GradientBoostingRegressor()
    dt = DecisionTreeRegressor()
    xgb = XGBRegressor()
       
    algos = [lr,r,l,e,kn,ext,gb,dt,xgb]
    algos_names = ['LinearRegressor','Ridge','Lasso','ElasticNet','KNeighbors','ExtraTree','GradientBoosting','DecisionTree','XGB']
    
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .2, random_state = 42)
    
    r_score = []
    mse = []
    mae = []
    
    result = pd.DataFrame(columns=['R_square','MSE','MAE'],index = algos_names)
    
    for algo in algos:
        pred = algo.fit(x,y).predict(x)
        r_score.append(r2_score(y,pred))
        mse.append(mean_squared_error(y,pred)**.5)
        mae.append(mean_absolute_error(y,pred))
    
    
    result.R_square=r_score
    result.MSE=mse
    result.MAE=mae
    
    return result.sort_values('R_square',ascending=False)

# %%
def classification_(train,y):
    
    
    g = GaussianNB()
    b = BernoulliNB()
    k = KNeighborsClassifier()
    svc = SVC()
    d = DecisionTreeClassifier()
    log = LogisticRegression()
    gbc = GradientBoostingClassifier()
    mn = MultinomialNB()
    rf = RandomForestClassifier()
    ab = AdaBoostClassifier()

    x = train
    y = y
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = .2, random_state=42)
    algos = [g,b,k,svc,d,log,gbc,mn,rf,ab]
    algos_name = ['Gaussian','Bernoulli','KNeigbors','SVC','DecisionTree','LogisticRegr','GradientBoosting','Multinominal','RandomForest','AdaBoost']
    
    accuracy = []
    precision = []
    recall = []
    f1 = []
   
    result = pd.DataFrame(columns=['AccuracyScore','PrecisionScore','RecallScore','f1_Score'],index = algos_name)
    
    for i in algos:
        
        predict = i.fit(x_train,y_train).predict(x_test)
        
        accuracy.append(accuracy_score(y_test,predict))
        precision.append(precision_score(y_test,predict))
        recall.append(recall_score(y_test,predict))
        f1.append(f1_score(y_test,predict))
        

    
    
    result.AccuracyScore = accuracy
    result.PrecisionScore = precision
    result.RecallScore = recall
    result.f1_Score = f1
    
    
    return result.sort_values('f1_Score',ascending=False)

# %%
df_sorted_pets = df_new.sort_values("pets")

# %%
del df_sorted_pets["pets"]

# %%
pets_deneme = pets_deneme.reset_index()

# %%
pets_oldu = pd.concat([df_sorted_pets,pets_deneme], axis=1)
pets_oldu
# Out:
#        age body_type                 diet    drinks      drugs  \
# 9494  28.0       fit      mostly anything  socially      never
# 6646  20.0      thin      mostly anything    rarely      never
# 415   59.0   average             anything  socially      never
# 7631  26.0   average    strictly anything  socially      never
# 5257  20.0   average      mostly anything  socially      never
# ...    ...       ...                  ...       ...        ...
# 9496  24.0   average      mostly anything  socially      never
# 9498  30.0  athletic  strictly vegetarian  socially      never
# 9502  31.0  athletic      mostly anything  socially      never
# 9507  41.0       fit      mostly anything  socially      never
# 9510  31.0  athletic      mostly anything  socially  sometimes
#
#                               education     ethnicity  height   income  \
# 9494  graduated from college/university  white, other    61.0     -1.0
# ...

# %%
del pets_oldu["index"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
del pets_oldu["level_0"]

# %%
pets_oldu.columns
# Out:
# Index([        'age',   'body_type',        'diet',      'drinks',
#              'drugs',   'education',   'ethnicity',      'height',
#             'income',         'job', 'last_online',    'location',
#        'orientation',    'religion',         'sex',        'sign',
#             'smokes',      'speaks',      'status',             0],
#       dtype='object')

# %%
pets_oldu.rename(columns = {0:'pets'}, inplace = True)

# %%
pets_oldu.head()
# Out:
#        age body_type               diet    drinks  drugs  \
# 9494  28.0       fit    mostly anything  socially  never
# 6646  20.0      thin    mostly anything    rarely  never
# 415   59.0   average           anything  socially  never
# 7631  26.0   average  strictly anything  socially  never
# 5257  20.0   average    mostly anything  socially  never
#
#                               education     ethnicity  height   income  \
# 9494  graduated from college/university  white, other    61.0     -1.0
# 6646  dropped out of college/university         other    71.0  70000.0
# 415   graduated from college/university         other    71.0     -1.0
# 7631          graduated from law school         white    70.0     -1.0
# 5257      working on college/university         white    67.0     -1.0
#
#                                job       last_online  \
# 9494                         other  2012-06-04-18-01
# 6646          education / academia  2012-06-29-23-46
# ...

# %%
df_sorted_religion = pets_oldu.sort_values("religion")

# %%
del df_sorted_religion["religion"]

# %%
religion_deneme = religion_deneme.reset_index()

# %%
religion_oldu = pd.concat([df_sorted_religion,religion_deneme], axis=1)
religion_oldu
# Out:
#        age       body_type                 diet    drinks  drugs  \
# 6479  31.0  a little extra      mostly anything  socially  never
# 913   42.0        athletic  strictly vegetarian    rarely  never
# 878   32.0            thin             anything  socially  never
# 862   27.0             fit      mostly anything  socially  never
# 6724  61.0  a little extra      mostly anything  socially  never
# ...    ...             ...                  ...       ...    ...
# 9475  68.0        athletic             anything  socially  never
# 9481  30.0  a little extra             anything  socially  never
# 9483  22.0         average      mostly anything  socially  never
# 9495  37.0        athletic             anything     often  never
# 9498  30.0        athletic  strictly vegetarian  socially  never
#
#                               education         ethnicity  height   income  \
# 6479            working on ph.d program             asian    71.0     -1.0
# ...

# %%
del religion_oldu["index"]

# %%
del religion_oldu["level_0"]

# %%
religion_oldu.rename(columns = {0:'religion'}, inplace = True)

# %%
df_sorted_sign = religion_oldu.sort_values("sign")

# %%
del df_sorted_sign["sign"]

# %%
sign_deneme = sign_deneme.reset_index()

# %%
sign_oldu = pd.concat([df_sorted_sign,sign_deneme], axis=1)
sign_oldu
# Out:
#        age body_type                 diet    drinks      drugs  \
# 1971  30.0     curvy      mostly anything  socially      never
# 1882  25.0   average      mostly anything  socially      never
# 5067  28.0   average      mostly anything  socially      never
# 4571  25.0   average             anything  socially  sometimes
# 4567  27.0     curvy      mostly anything  socially      never
# ...    ...       ...                  ...       ...        ...
# 9445  31.0      thin      mostly anything  socially      never
# 9458  25.0       fit      mostly anything  socially      never
# 9463  65.0       fit      mostly anything     often      never
# 9475  68.0  athletic             anything  socially      never
# 9498  30.0  athletic  strictly vegetarian  socially      never
#
#                               education         ethnicity  height   income  \
# 1971      working on college/university             white    64.0     -1.0
# ...

# %%
del sign_oldu["index"]

# %%
del sign_oldu["level_0"]

# %%
sign_oldu.rename(columns = {0:'sign'}, inplace = True)

# %%
sign_oldu
# Out:
#        age body_type                 diet    drinks      drugs  \
# 1971  30.0     curvy      mostly anything  socially      never
# 1882  25.0   average      mostly anything  socially      never
# 5067  28.0   average      mostly anything  socially      never
# 4571  25.0   average             anything  socially  sometimes
# 4567  27.0     curvy      mostly anything  socially      never
# ...    ...       ...                  ...       ...        ...
# 9445  31.0      thin      mostly anything  socially      never
# 9458  25.0       fit      mostly anything  socially      never
# 9463  65.0       fit      mostly anything     often      never
# 9475  68.0  athletic             anything  socially      never
# 9498  30.0  athletic  strictly vegetarian  socially      never
#
#                               education         ethnicity  height   income  \
# 1971      working on college/university             white    64.0     -1.0
# ...

# %%
sign_oldu.isnull().sum()
# Out:
# age            0
# body_type      0
# diet           0
# drinks         0
# drugs          0
# education      0
# ethnicity      0
# height         0
# income         0
# job            0
# last_online    0
# location       0
# orientation    0
# sex            0
# smokes         0
# speaks         0
# status         0
# pets           0
# religion       0
# sign           0
# dtype: int64

# %%
son_hal = sign_oldu

# %%
y = son_hal["age"]

# %%
del son_hal["age"]

# %%
son_hal_dm = pd.get_dummies(son_hal,drop_first=True)

# %%
son_hal_dm
# Out:
#       height   income  body_type_athletic  body_type_average  body_type_curvy  \
# 1971    64.0     -1.0                   0                  0                1
# 1882    76.0  80000.0                   0                  1                0
# 5067    69.0     -1.0                   0                  1                0
# 4571    74.0     -1.0                   0                  1                0
# 4567    66.0     -1.0                   0                  0                1
# ...      ...      ...                 ...                ...              ...
# 9445    70.0     -1.0                   0                  0                0
# 9458    70.0     -1.0                   0                  0                0
# 9463    66.0     -1.0                   0                  0                0
# 9475    70.0     -1.0                   1                  0                0
# 9498    60.0     -1.0                   1                  0                0
#
# ...

# %%
#regression_(son_hal_dm,y)

# %%
#model = LinearRegression().fit(son_hal_dm,y)

# %%
x_train,x_test,y_train,y_test=train_test_split(son_hal_dm,y,test_size = .2, random_state=42)
cls = DecisionTreeClassifier().fit(x_train,y_train)

# %%
tahmin = cls.predict(x_test)

# %%
tahmin
# Out:
# array([30., 35., 28., ..., 20., 31., 34.])

# %%
len(tahmin)
# Out:
# 1903

# %%
generation  = []
for i in tahmin:
    if (18<i<32):
        generation.append("Millennial")
    elif (33<i<47):
        generation.append("Gen X-er")
    elif (48<i<70):
        generation.append("Boomers")
    else:
        generation.append("other")

# %%
len(generation)
# Out:
# 1903

# %%
generation
# Out:
# ['Millennial',
#  'Gen X-er',
#  'Millennial',
#  'Millennial',
#  'Boomers',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Gen X-er',
#  'Gen X-er',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'other',
#  'Gen X-er',
#  'Millennial',
#  'Millennial',
#  'other',
#  'Millennial',
#  'Millennial',
#  'Gen X-er',
#  'Millennial',
#  'Millennial',
#  'Gen X-er',
#  'Gen X-er',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Boomers',
#  'Millennial',
#  'Gen X-er',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'other',
#  'Boomers',
#  'Gen X-er',
#  'Gen X-er',
#  'Millennial',
#  'Millennial',
#  'Gen X-er',
#  'other',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Millennial',
#  'Gen X-er',
#  'Millennial',
#  'Gen X-er',
# ...
