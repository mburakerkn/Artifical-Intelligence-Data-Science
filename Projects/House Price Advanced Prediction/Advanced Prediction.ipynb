# %% [markdown]
# # Advanced Prediction

# %%
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv("train.csv")
df2 = pd.read_csv("test.csv")

# %%
df1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df1.shape
# Out:
# (1460, 81)

# %%
df2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df2.shape
# Out:
# (1459, 80)

# %%
df = df1.append(df2)

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1454         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (2919, 81)

# %%
df.select_dtypes("object").columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
df = df[['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
       'SaleType', 'SaleCondition',"SalePrice","OverallQual","GrLivArea","GarageCars","GarageArea","TotalBsmtSF","1stFlrSF","FullBath","TotRmsAbvGrd","YearBuilt","YearRemodAdd","GarageYrBlt","MasVnrArea","Fireplaces","BsmtFinSF1","LotFrontage","WoodDeckSF","2ndFlrSF","OpenPorchSF","HalfBath"]]

# %%
df = df.drop(columns=["Utilities"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       2915 non-null   object
#  1   Street         2919 non-null   object
#  2   Alley          198 non-null    object
#  3   LotShape       2919 non-null   object
#  4   LandContour    2919 non-null   object
#  5   LotConfig      2919 non-null   object
#  6   LandSlope      2919 non-null   object
#  7   Neighborhood   2919 non-null   object
#  8   Condition1     2919 non-null   object
#  9   Condition2     2919 non-null   object
#  10  BldgType       2919 non-null   object
#  11  HouseStyle     2919 non-null   object
#  12  RoofStyle      2919 non-null   object
#  13  RoofMatl       2919 non-null   object
#  14  Exterior1st    2918 non-null   object
#  15  Exterior2nd    2918 non-null   object
#  16  MasVnrType     2895 non-null   object
# ...

# %%
df.head()
# Out:
#   MSZoning Street Alley LotShape LandContour LotConfig LandSlope Neighborhood  \
# 0       RL   Pave   NaN      Reg         Lvl    Inside       Gtl      CollgCr
# 1       RL   Pave   NaN      Reg         Lvl       FR2       Gtl      Veenker
# 2       RL   Pave   NaN      IR1         Lvl    Inside       Gtl      CollgCr
# 3       RL   Pave   NaN      IR1         Lvl    Corner       Gtl      Crawfor
# 4       RL   Pave   NaN      IR1         Lvl       FR2       Gtl      NoRidge
#
#   Condition1 Condition2  ... YearRemodAdd GarageYrBlt MasVnrArea Fireplaces  \
# 0       Norm       Norm  ...         2003      2003.0      196.0          0
# 1      Feedr       Norm  ...         1976      1976.0        0.0          1
# 2       Norm       Norm  ...         2002      2001.0      162.0          1
# 3       Norm       Norm  ...         1970      1998.0        0.0          1
# 4       Norm       Norm  ...         2000      2000.0      350.0          1
#
# ...

# %%
#df_dummies = pd.get_dummies(df_new,drop_first=True)

# %%
df["MasVnrArea"].fillna(df["MasVnrArea"].mean(),inplace=True)

# %%
df["GarageYrBlt"].fillna(0,inplace=True)

# %%
df["MSZoning"].fillna("RL",inplace=True)

# %%
df["Exterior1st"].fillna("VinylSd",inplace=True)

# %%
df["Exterior2nd"].fillna("VinylSd",inplace=True)

# %%
df["MasVnrType"].fillna("None",inplace=True)

# %%
df["BsmtQual"].fillna("None",inplace=True,limit=40)

# %%
df["BsmtCond"].fillna("None",inplace=True)

# %%
df["BsmtExposure"].fillna("None",inplace=True,limit=62)

# %%
df["BsmtFinType1"].fillna("None",inplace=True,limit=40)

# %%
df["BsmtFinType2"].fillna("None",inplace=True)

# %%
df["Electrical"].fillna("SBrkr",inplace=True)

# %%
df["KitchenQual"].fillna("TA",inplace=True)

# %%
df["Functional"].fillna("Typ",inplace=True)

# %%
df["SaleType"].fillna("WD",inplace=True)

# %%
df["BsmtFinSF1"].fillna(0.0,inplace=True)

# %%
df["TotalBsmtSF"].fillna(0.0,inplace=True)

# %%
df["GarageCars"].fillna(0.0,inplace=True)

# %%
df["GarageArea"].fillna(0.0,inplace=True)

# %%
df["GarageType"].fillna("None",inplace=True)

# %%
df["GarageFinish"].fillna("None",inplace=True,limit=90)

# %%
df["GarageFinish"].fillna("RFn",inplace=True,limit=69)

# %%
df["GarageQual"].fillna("None",inplace=True)

# %%
df["GarageCond"].fillna("None",inplace=True)

# %%
df["PoolQC"].fillna("None",inplace=True)

# %%
df["MiscFeature"].fillna("None",inplace=True)

# %%
df["Alley"].fillna("None",inplace=True)

# %%
df["FireplaceQu"].fillna("None",inplace=True)

# %%
df["Fence"].fillna("None",inplace=True)

# %%
df["LotFrontage"].fillna(65,inplace=True)

# %%
df["GarageType"].value_counts()
# Out:
# Attchd     1723
# Detchd      779
# BuiltIn     186
# None        157
# Basment      36
# 2Types       23
# CarPort      15
# Name: GarageType, dtype: int64

# %%
df.isnull().sum()
# Out:
# MSZoning       0
# Street         0
# Alley          0
# LotShape       0
# LandContour    0
#               ..
# LotFrontage    0
# WoodDeckSF     0
# 2ndFlrSF       0
# OpenPorchSF    0
# HalfBath       0
# Length: 62, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       2919 non-null   object
#  1   Street         2919 non-null   object
#  2   Alley          2919 non-null   object
#  3   LotShape       2919 non-null   object
#  4   LandContour    2919 non-null   object
#  5   LotConfig      2919 non-null   object
#  6   LandSlope      2919 non-null   object
#  7   Neighborhood   2919 non-null   object
#  8   Condition1     2919 non-null   object
#  9   Condition2     2919 non-null   object
#  10  BldgType       2919 non-null   object
#  11  HouseStyle     2919 non-null   object
#  12  RoofStyle      2919 non-null   object
#  13  RoofMatl       2919 non-null   object
#  14  Exterior1st    2919 non-null   object
#  15  Exterior2nd    2919 non-null   object
#  16  MasVnrType     2919 non-null   object
# ...

# %% [markdown]
# # Düzenleme

# %%
df = df[df["LotFrontage"]<150]
df["YearBuilt"] = 2022-df["YearBuilt"]
df["YearRemodAdd"] = 2022-df["YearRemodAdd"]
df = df[df["GrLivArea"]<3000]
df = df[df["GarageCars"]<4]
df = df[df["GarageArea"]<1000]
df = df[df["TotalBsmtSF"]<3000]
df = df[df["1stFlrSF"]<3000]
df = df[df["TotRmsAbvGrd"]<11]
df["GarageYrBlt"] = 2022-df["GarageYrBlt"]
df = df[df["GarageYrBlt"]>0]
df = df[df["Fireplaces"]<3]
df = df[df["BsmtFinSF1"]<2000]
df = df[df["WoodDeckSF"]<=400]
df = df[df["2ndFlrSF"]<1500]
df = df[df["OpenPorchSF"]<300]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2700 entries, 0 to 1458
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       2700 non-null   object
#  1   Street         2700 non-null   object
#  2   Alley          2700 non-null   object
#  3   LotShape       2700 non-null   object
#  4   LandContour    2700 non-null   object
#  5   LotConfig      2700 non-null   object
#  6   LandSlope      2700 non-null   object
#  7   Neighborhood   2700 non-null   object
#  8   Condition1     2700 non-null   object
#  9   Condition2     2700 non-null   object
#  10  BldgType       2700 non-null   object
#  11  HouseStyle     2700 non-null   object
#  12  RoofStyle      2700 non-null   object
#  13  RoofMatl       2700 non-null   object
#  14  Exterior1st    2700 non-null   object
#  15  Exterior2nd    2700 non-null   object
#  16  MasVnrType     2700 non-null   object
# ...

# %%
df["SalePrice"].head()
# Out:
# 0    208500.0
# 1    181500.0
# 2    223500.0
# 3    140000.0
# 4    250000.0
# Name: SalePrice, dtype: float64

# %%
dfx = df[:1349]

# %%
y = df["SalePrice"][:1349]

# %%
dfx = dfx.drop(columns=['SalePrice'])

# %%
dfx = pd.get_dummies(dfx,drop_first=True)

# %%
dfx.shape , y.shape
# Out:
# ((1349, 235), (1349,))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)

#Regression
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.preprocessing import normalize,scale

# %%
def regression_(x,y):
    
    lr = LinearRegression()
    r = Ridge()
    l = Lasso()
    e = ElasticNet()
    kn = KNeighborsRegressor()
    ext = ExtraTreeRegressor()
    gb = GradientBoostingRegressor()
    dt = DecisionTreeRegressor()
    xgb = XGBRegressor()
       
    algos = [lr,r,l,e,kn,ext,gb,dt,xgb]
    algos_names = ['LinearRegressor','Ridge','Lasso','ElasticNet','KNeighbors','ExtraTree','GradientBoosting','DecisionTree','XGB']
    
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .2, random_state = 42)
    
    r_score = []
    mse = []
    mae = []
    
    result = pd.DataFrame(columns=['R_square','MSE','MAE'],index = algos_names)
    
    for algo in algos:
        pred = algo.fit(x,y).predict(x)
        r_score.append(r2_score(y,pred))
        mse.append(mean_squared_error(y,pred)**.5)
        mae.append(mean_absolute_error(y,pred))
    
    
    result.R_square=r_score
    result.MSE=mse
    result.MAE=mae
    
    return result.sort_values('R_square',ascending=False)

# %%
regression_(dfx,y)
# Out:
#                   R_square           MSE           MAE
# ExtraTree         0.999995    144.391055      5.559674
# DecisionTree      0.999995    144.391055      5.559674
# XGB               0.999235   1843.470023   1303.084058
# GradientBoosting  0.956587  13885.725161  10369.728108
# LinearRegressor   0.936452  16799.889827  12005.464624
# Lasso             0.936304  16819.490639  12020.834633
# Ridge             0.935083  16979.963146  12138.715647
# ElasticNet        0.872844  23764.267566  16713.781815
# KNeighbors        0.836076  26982.228340  18445.664196
