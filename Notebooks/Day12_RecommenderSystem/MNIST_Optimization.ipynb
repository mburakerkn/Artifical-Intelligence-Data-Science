# %% [markdown]
# # MNIST Optimization

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape(60000, 784)
test_images = test_images.reshape(10000, 784)
test_images = test_images.astype("float32")
train_images = train_images.astype("float32")
test_images/= 255
train_images/= 255
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation="relu", input_shape=(784,)),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")])
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size=128, epochs=40, verbose=1, validation_data=(test_images,test_labels))
# Out:
# 2022-08-07 19:05:15.407858: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/40
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3986 - accuracy: 0.8857 - val_loss: 0.1922 - val_accuracy: 0.9430
# Epoch 2/40
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1687 - accuracy: 0.9511 - val_loss: 0.1413 - val_accuracy: 0.9576
# Epoch 3/40
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1223 - accuracy: 0.9635 - val_loss: 0.1210 - val_accuracy: 0.9651
# Epoch 4/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0971 - accuracy: 0.9712 - val_loss: 0.1068 - val_accuracy: 0.9668
# Epoch 5/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0800 - accuracy: 0.9754 - val_loss: 0.1036 - val_accuracy: 0.9692
# Epoch 6/40
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0678 - accuracy: 0.9797 - val_loss: 0.0975 - val_accuracy: 0.9698
# Epoch 7/40
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0584 - accuracy: 0.9821 - val_loss: 0.0894 - val_accuracy: 0.9730
# Epoch 8/40
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0492 - accuracy: 0.9855 - val_loss: 0.0904 - val_accuracy: 0.9737
# Epoch 9/40
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0445 - accuracy: 0.9862 - val_loss: 0.0897 - val_accuracy: 0.9733
# Epoch 10/40
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0374 - accuracy: 0.9887 - val_loss: 0.0844 - val_accuracy: 0.9758
# Epoch 11/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0318 - accuracy: 0.9909 - val_loss: 0.0859 - val_accuracy: 0.9749
# Epoch 12/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0289 - accuracy: 0.9913 - val_loss: 0.1034 - val_accuracy: 0.9728
# Epoch 13/40
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0255 - accuracy: 0.9924 - val_loss: 0.0893 - val_accuracy: 0.9760
# Epoch 14/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0227 - accuracy: 0.9929 - val_loss: 0.1013 - val_accuracy: 0.9734
# Epoch 15/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0204 - accuracy: 0.9938 - val_loss: 0.0963 - val_accuracy: 0.9766
# Epoch 16/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0171 - accuracy: 0.9948 - val_loss: 0.1134 - val_accuracy: 0.9723
# Epoch 17/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.1018 - val_accuracy: 0.9752
# Epoch 18/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.1011 - val_accuracy: 0.9751
# Epoch 19/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.1103 - val_accuracy: 0.9744
# Epoch 20/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.1163 - val_accuracy: 0.9742
# Epoch 21/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.9972 - val_loss: 0.1246 - val_accuracy: 0.9729
# Epoch 22/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 0.1178 - val_accuracy: 0.9746
# Epoch 23/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.1198 - val_accuracy: 0.9760
# Epoch 24/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.1246 - val_accuracy: 0.9756
# Epoch 25/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.1225 - val_accuracy: 0.9749
# Epoch 26/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.1444 - val_accuracy: 0.9709
# Epoch 27/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 0.1359 - val_accuracy: 0.9739
# Epoch 28/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.1289 - val_accuracy: 0.9754
# Epoch 29/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.1280 - val_accuracy: 0.9758
# Epoch 30/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1403 - val_accuracy: 0.9735
# Epoch 31/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.1546 - val_accuracy: 0.9714
# Epoch 32/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.1449 - val_accuracy: 0.9739
# Epoch 33/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.1484 - val_accuracy: 0.9729
# Epoch 34/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.1438 - val_accuracy: 0.9756
# Epoch 35/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.1383 - val_accuracy: 0.9757
# Epoch 36/40
# 469/469 [==============================] - 1s 3ms/step - loss: 9.9106e-04 - accuracy: 0.9999 - val_loss: 0.1353 - val_accuracy: 0.9763
# Epoch 37/40
# 469/469 [==============================] - 1s 3ms/step - loss: 3.4486e-04 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 0.9780
# Epoch 38/40
# 469/469 [==============================] - 1s 3ms/step - loss: 2.5467e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9783
# Epoch 39/40
# 469/469 [==============================] - 2s 3ms/step - loss: 2.2961e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9785
# Epoch 40/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.2041 - val_accuracy: 0.9685

# %%
_, accuracy = model.evaluate(test_images, test_labels)
print("Accuracy: %.2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1222 - accuracy: 0.9771
# Accuracy: 97.71

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train","Test"], loc="upper left")
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train","Test"], loc="upper left")
plt.show()

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape(60000, 784)
test_images = test_images.reshape(10000, 784)
test_images = test_images.astype("float32")
train_images = train_images.astype("float32")
test_images/= 255
train_images/= 255
model = tf.keras.Sequential([
    tf.keras.layers.Dense(512, activation="relu", input_shape=(784,)),
    tf.keras.layers.Dense(512, activation="relu"),
    tf.keras.layers.Dense(512, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")])
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size=128, epochs=40, verbose=1, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/40
# 469/469 [==============================] - 5s 10ms/step - loss: 0.2135 - accuracy: 0.9359 - val_loss: 0.1163 - val_accuracy: 0.9641
# Epoch 2/40
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0828 - accuracy: 0.9751 - val_loss: 0.0836 - val_accuracy: 0.9739
# Epoch 3/40
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0553 - accuracy: 0.9821 - val_loss: 0.1111 - val_accuracy: 0.9696
# Epoch 4/40
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0425 - accuracy: 0.9861 - val_loss: 0.0869 - val_accuracy: 0.9757
# Epoch 5/40
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0319 - accuracy: 0.9897 - val_loss: 0.0809 - val_accuracy: 0.9786
# Epoch 6/40
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0284 - accuracy: 0.9906 - val_loss: 0.0727 - val_accuracy: 0.9822
# Epoch 7/40
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0212 - accuracy: 0.9934 - val_loss: 0.0736 - val_accuracy: 0.9802
# Epoch 8/40
# 469/469 [==============================] - 6s 14ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.0885 - val_accuracy: 0.9780
# Epoch 9/40
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.0844 - val_accuracy: 0.9779
# Epoch 10/40
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.0883 - val_accuracy: 0.9758
# Epoch 11/40
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0173 - accuracy: 0.9945 - val_loss: 0.0877 - val_accuracy: 0.9789
# Epoch 12/40
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0155 - accuracy: 0.9952 - val_loss: 0.0837 - val_accuracy: 0.9812
# Epoch 13/40
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.1001 - val_accuracy: 0.9781
# Epoch 14/40
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0957 - val_accuracy: 0.9809
# Epoch 15/40
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0135 - accuracy: 0.9961 - val_loss: 0.0790 - val_accuracy: 0.9811
# Epoch 16/40
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0853 - val_accuracy: 0.9818
# Epoch 17/40
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.0852 - val_accuracy: 0.9830
# Epoch 18/40
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.1280 - val_accuracy: 0.9776
# Epoch 19/40
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.0799 - val_accuracy: 0.9821
# Epoch 20/40
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.1004 - val_accuracy: 0.9800
# Epoch 21/40
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.0910 - val_accuracy: 0.9806
# Epoch 22/40
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0091 - accuracy: 0.9976 - val_loss: 0.0777 - val_accuracy: 0.9834
# Epoch 23/40
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.1022 - val_accuracy: 0.9809
# Epoch 24/40
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.1010 - val_accuracy: 0.9787
# Epoch 25/40
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0948 - val_accuracy: 0.9814
# Epoch 26/40
# 469/469 [==============================] - 16s 34ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0835 - val_accuracy: 0.9846
# Epoch 27/40
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.1109 - val_accuracy: 0.9812
# Epoch 28/40
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.0816 - val_accuracy: 0.9834
# Epoch 29/40
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.1130 - val_accuracy: 0.9796
# Epoch 30/40
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.1129 - val_accuracy: 0.9802
# Epoch 31/40
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.0936 - val_accuracy: 0.9837
# Epoch 32/40
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.1072 - val_accuracy: 0.9817
# Epoch 33/40
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.0851 - val_accuracy: 0.9847
# Epoch 34/40
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1036 - val_accuracy: 0.9835
# Epoch 35/40
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.1125 - val_accuracy: 0.9780
# Epoch 36/40
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0945 - val_accuracy: 0.9833
# Epoch 37/40
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.1064 - val_accuracy: 0.9851
# Epoch 38/40
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.1310 - val_accuracy: 0.9823
# Epoch 39/40
# 469/469 [==============================] - 10s 20ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 0.1390 - val_accuracy: 0.9807
# Epoch 40/40
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.1113 - val_accuracy: 0.9838

# %%
_, accuracy = model.evaluate(test_images, test_labels)
print("Accuracy: %.2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1113 - accuracy: 0.9838
# Accuracy: 98.38

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train","Test"], loc="upper left")
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train","Test"], loc="upper left")
plt.show()

# %% [markdown]
# # CNN Convolutional Neural Network

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape(60000, 28, 28, 1)
test_images = test_images.reshape(10000, 28, 28, 1)

train_images, test_images = train_images/255.0, test_images/255.0


model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation="relu", input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(100, activation="softmax")])
model.compile(optimizer = tf.keras.optimizers.SGD(lr=0.01, momentum=0.9), loss="sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size=32, epochs=10, verbose=1, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# /opt/anaconda3/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 1875/1875 [==============================] - 22s 11ms/step - loss: 0.2901 - accuracy: 0.9151 - val_loss: 0.1307 - val_accuracy: 0.9604
# Epoch 2/10
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0937 - accuracy: 0.9716 - val_loss: 0.0787 - val_accuracy: 0.9748
# Epoch 3/10
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.0575 - accuracy: 0.9823 - val_loss: 0.0561 - val_accuracy: 0.9808
# Epoch 4/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0404 - accuracy: 0.9878 - val_loss: 0.0552 - val_accuracy: 0.9804
# Epoch 5/10
# 1875/1875 [==============================] - 42s 22ms/step - loss: 0.0296 - accuracy: 0.9906 - val_loss: 0.0498 - val_accuracy: 0.9837
# Epoch 6/10
# 1875/1875 [==============================] - 56s 30ms/step - loss: 0.0231 - accuracy: 0.9930 - val_loss: 0.0443 - val_accuracy: 0.9858
# Epoch 7/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.0471 - val_accuracy: 0.9850
# Epoch 8/10
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.0118 - accuracy: 0.9966 - val_loss: 0.0510 - val_accuracy: 0.9854
# Epoch 9/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0476 - val_accuracy: 0.9855
# Epoch 10/10
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.0479 - val_accuracy: 0.9857

# %%
_, accuracy = model.evaluate(test_images, test_labels)
print("Accuracy: %.2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0479 - accuracy: 0.9857
# Accuracy: 98.57

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape(60000, 28, 28, 1)
test_images = test_images.reshape(10000, 28, 28, 1)

train_images, test_images = train_images/255.0, test_images/255.0


model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation="relu", input_shape=(28, 28, 1)),
    tf.keras.layers.Conv2D(64,(3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")])
model.compile(optimizer = tf.keras.optimizers.SGD(lr=0.01, momentum=0.9), loss="sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size=32, epochs=10, verbose=1, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 165s 88ms/step - loss: 0.1905 - accuracy: 0.9433 - val_loss: 0.0607 - val_accuracy: 0.9803
# Epoch 2/10
# 1875/1875 [==============================] - 169s 90ms/step - loss: 0.0527 - accuracy: 0.9841 - val_loss: 0.0459 - val_accuracy: 0.9843
# Epoch 3/10
# 1875/1875 [==============================] - 141s 75ms/step - loss: 0.0335 - accuracy: 0.9890 - val_loss: 0.0444 - val_accuracy: 0.9854
# Epoch 4/10
# 1875/1875 [==============================] - 147s 78ms/step - loss: 0.0218 - accuracy: 0.9929 - val_loss: 0.0392 - val_accuracy: 0.9873
# Epoch 5/10
# 1875/1875 [==============================] - 130s 69ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.0317 - val_accuracy: 0.9904
# Epoch 6/10
# 1875/1875 [==============================] - 127s 68ms/step - loss: 0.0101 - accuracy: 0.9968 - val_loss: 0.0424 - val_accuracy: 0.9883
# Epoch 7/10
# 1875/1875 [==============================] - 137s 73ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.0412 - val_accuracy: 0.9903
# Epoch 8/10
# 1875/1875 [==============================] - 129s 69ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0376 - val_accuracy: 0.9898
# Epoch 9/10
# 1875/1875 [==============================] - 130s 69ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0390 - val_accuracy: 0.9904
# Epoch 10/10
# 1875/1875 [==============================] - 125s 67ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0422 - val_accuracy: 0.9902

# %%
_, accuracy = model.evaluate(test_images, test_labels)
print("Accuracy: %.2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0422 - accuracy: 0.9902
# Accuracy: 99.02

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train","Test"], loc="upper left")
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train","Test"], loc="upper left")
plt.show()

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape(60000, 28, 28, 1)
test_images = test_images.reshape(10000, 28, 28, 1)

train_images, test_images = train_images/255.0, test_images/255.0


model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation="relu", input_shape=(28, 28, 1)),
    tf.keras.layers.Conv2D(64,(3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation="softmax")])
model.compile(optimizer = tf.keras.optimizers.SGD(lr=0.01, momentum=0.9), loss="sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size=32, epochs=10, verbose=1, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 211s 112ms/step - loss: 0.3088 - accuracy: 0.9040 - val_loss: 0.0642 - val_accuracy: 0.9803
# Epoch 2/10
# 1875/1875 [==============================] - 185s 99ms/step - loss: 0.1145 - accuracy: 0.9659 - val_loss: 0.0496 - val_accuracy: 0.9845
# Epoch 3/10
# 1875/1875 [==============================] - 172s 92ms/step - loss: 0.0845 - accuracy: 0.9751 - val_loss: 0.0393 - val_accuracy: 0.9858
# Epoch 4/10
# 1875/1875 [==============================] - 180s 96ms/step - loss: 0.0702 - accuracy: 0.9788 - val_loss: 0.0338 - val_accuracy: 0.9896
# Epoch 5/10
# 1875/1875 [==============================] - 169s 90ms/step - loss: 0.0622 - accuracy: 0.9807 - val_loss: 0.0330 - val_accuracy: 0.9896
# Epoch 6/10
# 1875/1875 [==============================] - 186s 99ms/step - loss: 0.0557 - accuracy: 0.9827 - val_loss: 0.0268 - val_accuracy: 0.9917
# Epoch 7/10
# 1875/1875 [==============================] - 248s 132ms/step - loss: 0.0487 - accuracy: 0.9841 - val_loss: 0.0326 - val_accuracy: 0.9904
# Epoch 8/10
# 1875/1875 [==============================] - 249s 133ms/step - loss: 0.0458 - accuracy: 0.9859 - val_loss: 0.0290 - val_accuracy: 0.9904
# Epoch 9/10
# 1875/1875 [==============================] - 237s 127ms/step - loss: 0.0414 - accuracy: 0.9863 - val_loss: 0.0304 - val_accuracy: 0.9904
# Epoch 10/10
# 1875/1875 [==============================] - 297s 158ms/step - loss: 0.0386 - accuracy: 0.9878 - val_loss: 0.0302 - val_accuracy: 0.9897

# %%
_, accuracy = model.evaluate(test_images, test_labels)
print("Accuracy: %.2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 15s 45ms/step - loss: 0.0302 - accuracy: 0.9897
# Accuracy: 98.97

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train","Test"], loc="upper left")
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train","Test"], loc="upper left")
plt.show()

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
type(train_images)
# Out:
# numpy.ndarray

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape(60000, 28, 28, 1)
test_images = test_images.reshape(10000, 28, 28, 1)

train_images, test_images = train_images/255.0, test_images/255.0


model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation="relu", input_shape=(28, 28, 1)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64,(3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation="softmax")])
model.compile(optimizer = tf.keras.optimizers.SGD(lr=0.01, momentum=0.9), loss="sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size=32, epochs=10, verbose=1, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 200s 107ms/step - loss: 0.1012 - accuracy: 0.9698 - val_loss: 0.0525 - val_accuracy: 0.9836
# Epoch 2/10
# 1875/1875 [==============================] - 177s 94ms/step - loss: 0.0388 - accuracy: 0.9880 - val_loss: 0.0341 - val_accuracy: 0.9889
# Epoch 3/10
# 1875/1875 [==============================] - 160s 85ms/step - loss: 0.0246 - accuracy: 0.9927 - val_loss: 0.0305 - val_accuracy: 0.9895
# Epoch 4/10
# 1875/1875 [==============================] - 186s 99ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.0324 - val_accuracy: 0.9890
# Epoch 5/10
# 1875/1875 [==============================] - 153s 81ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.0317 - val_accuracy: 0.9907
# Epoch 6/10
# 1875/1875 [==============================] - 193s 103ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.0287 - val_accuracy: 0.9909
# Epoch 7/10
# 1875/1875 [==============================] - 200s 107ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0308 - val_accuracy: 0.9912
# Epoch 8/10
# 1875/1875 [==============================] - 219s 117ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.0328 - val_accuracy: 0.9907
# Epoch 9/10
# 1875/1875 [==============================] - 177s 95ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0302 - val_accuracy: 0.9911
# Epoch 10/10
# 1875/1875 [==============================] - 165s 88ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0318 - val_accuracy: 0.9916

# %%
_, accuracy = model.evaluate(test_images, test_labels)
print("Accuracy: %.2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 7s 23ms/step - loss: 0.0318 - accuracy: 0.9916
# Accuracy: 99.16

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train","Test"], loc="upper left")
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train","Test"], loc="upper left")
plt.show()
