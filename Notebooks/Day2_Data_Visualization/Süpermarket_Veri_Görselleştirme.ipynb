# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("supermarket.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 995   40.35                 4.761905        2.0175     6.2
# 996  973.80                 4.761905       48.6900     4.4
# 997   31.84                 4.761905        1.5920     7.7
# 998   65.82                 4.761905        3.2910     4.1
# 999  618.38                 4.761905       30.9190     6.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.sample(7)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 180  130-98-8941      C  Naypyitaw        Normal    Male  Fashion accessories
# 880  490-95-0021      B   Mandalay        Member  Female   Food and beverages
# 980  728-47-9078      C  Naypyitaw        Member    Male   Food and beverages
# 427  650-98-6268      B   Mandalay        Member  Female   Food and beverages
# 186  305-14-0245      B   Mandalay        Member  Female   Home and lifestyle
# 461  234-03-4040      B   Mandalay        Member  Female   Food and beverages
# 802  474-33-8305      C  Naypyitaw        Member    Male  Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 180       64.26         7  22.4910  472.3110   2/9/2019  10:00         Cash
# 880       33.21        10  16.6050  348.7050   1/8/2019  14:25      Ewallet
# 980       59.59         4  11.9180  250.2780  1/19/2019  12:46         Cash
# 427       20.87         3   3.1305   65.7405  3/20/2019  13:53  Credit card
# 186       94.49         8  37.7960  793.7160   3/3/2019  19:00      Ewallet
# 461       73.05        10  36.5250  767.0250   3/3/2019  12:25  Credit card
# 802       67.39         7  23.5865  495.3165  3/23/2019  13:23      Ewallet
#
#        cogs  gross margin percentage  gross income  Rating
# 180  449.82                 4.761905       22.4910     5.7
# 880  332.10                 4.761905       16.6050     6.0
# 980  238.36                 4.761905       11.9180     9.8
# 427   62.61                 4.761905        3.1305     8.0
# 186  755.92                 4.761905       37.7960     7.5
# 461  730.50                 4.761905       36.5250     8.7
# 802  471.73                 4.761905       23.5865     6.9

# %%
df.City.unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df.City.nunique()
# Out:
# 3

# %%
df["Branch"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["month_name"].unique()
# Out:
# array(['January', 'March', 'February'], dtype=object)

# %%
df["Branch"].nunique()
# Out:
# 3

# %%
df.Total.max()
# Out:
# 1042.65

# %%
df["Total"].max(),df["Total"].min(),df["Total"].std(),df["Total"].var()
# Out:
# (1042.65, 10.6785, 245.88533510097207, 60459.598017717326)

# %%
df.Date=pd.to_datetime(df.Date)

# %%
df.day = (df.Date).dt.day
df["month"]=(df["Date"]).dt.month
df["year"]=(df["Date"]).dt.year

# %%
df["month_name"]=df["Date"].dt.month_name()

# %%
df["weekday"]=df["Date"].dt.day_name()

# %%
df["Time"]=pd.to_datetime(df.Time)

# %%
df["Hour"]=(df["Time"]).dt.hour

# %%
sns.countplot(df["month_name"]);

# %%
plt.figure(figsize=(10,6));
plt.title("Monthly Transaction");
sns.countplot(df["month_name"]);
plt.xticks(rotation=20);

# %%
plt.figure(figsize=(5,5))
plt.title("Male vs Female Customers")
sns.countplot(df.Gender);

# %%
df.month_name.value_counts()
# Out:
# January     352
# March       345
# February    303
# Name: month_name, dtype: int64

# %%
df["weekday"].value_counts()
# Out:
# Saturday     164
# Tuesday      158
# Wednesday    143
# Friday       139
# Thursday     138
# Sunday       133
# Monday       125
# Name: weekday, dtype: int64

# %%
sns.countplot(df.weekday);
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(7,7))
explode=(0.05,0.05,0.05)
df["month_name"].value_counts().plot.pie(autopct="%1.1f%%",startangle=60,explode=explode)
plt.title("Transaction per month")
# Out:
# Text(0.5, 1.0, 'Transaction per month')

# %%
plt.figure(figsize=(8,8))
explode=(0.05,0.05,0.05,0.05,0.05,0.05)
df["Product line"].value_counts().plot.pie(autopct="%1.1f%%",startangle=120,explode=explode)
plt.title("Transaction per month")
# Out:
# Text(0.5, 1.0, 'Transaction per month')

# %%
sns.countplot(df["Product line"])
plt.xticks(rotation=70);

# %%
plt.figure(figsize=(12,6))
plt.title("Total Monthly Transaction")
sns.countplot(df["Product line"])
# Out:
# <AxesSubplot:title={'center':'Total Monthly Transaction'}, xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(12,9))
plt.title("Total Monthly transaction")
sns.countplot(df.Branch,hue=df["Product line"])
# Out:
# <AxesSubplot:title={'center':'Total Monthly transaction'}, xlabel='Branch', ylabel='count'>

# %%
plt.title("Countplot of Customer Types")
sns.countplot(df["Customer type"])
# Out:
# <AxesSubplot:title={'center':'Countplot of Customer Types'}, xlabel='Customer type', ylabel='count'>

# %%
plt.title("total monthly transaction")
sns.countplot(df["City"],hue=df.Branch)
# Out:
# <AxesSubplot:title={'center':'total monthly transaction'}, xlabel='City', ylabel='count'>

# %%
sns.barplot(x = df.City,y = df.index,palette="hot");

# %%
plt.title("Frequency of purchases genderwise")
sns.countplot(df["Gender"],hue=df.City);

# %%
sns.barplot(x=df.Payment,y=df.index);

# %%
plt.figure(figsize=(13,9))
sns.barplot(x=df["Product line"],y=df["gross income"]);

# %%
plt.figure(figsize=(13,9))
sns.barplot(x=df["Product line"],y=df["gross income"]);
plt.xticks(rotation=60)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Health and beauty'),
#   Text(1, 0, 'Electronic accessories'),
#   Text(2, 0, 'Home and lifestyle'),
#   Text(3, 0, 'Sports and travel'),
#   Text(4, 0, 'Food and beverages'),
#   Text(5, 0, 'Fashion accessories')])

# %%
plt.figure(figsize=(13,9))
sns.barplot(y=df["Product line"],x=df["gross income"]);

# %%
plt.figure(figsize=(13,9))
sns.barplot(x=df["Product line"],y=df["Rating"]);

# %%
plt.figure(figsize=(13,9))
sns.barplot(x=df["Total"],y=df["Product line"]);

# %%
plt.figure(figsize=(13,9))
sns.distplot(df.Quantity);

# %%
df["Hour"].unique()
# Out:
# array([13, 10, 20, 18, 14, 11, 17, 16, 19, 15, 12])

# %%
df["Hour"].nunique()
# Out:
# 11

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating        month    year
# count             1.000000e+03   1000.000000  1000.00000  1000.000000  1000.0
# mean              4.761905e+00     15.379369     6.97270     1.993000  2019.0
# std               6.131498e-14     11.708825     1.71858     0.835254     0.0
# min               4.761905e+00      0.508500     4.00000     1.000000  2019.0
# 25%               4.761905e+00      5.924875     5.50000     1.000000  2019.0
# 50%               4.761905e+00     12.088000     7.00000     2.000000  2019.0
# 75%               4.761905e+00     22.445250     8.50000     3.000000  2019.0
# max               4.761905e+00     49.650000    10.00000     3.000000  2019.0

# %%
df["weekday"].nunique()
# Out:
# 7
